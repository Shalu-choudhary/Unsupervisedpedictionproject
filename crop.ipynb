# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("https://raw.githubusercontent.com/upflairs-pvt-ltd/JECRC-20april2024/main/farmer.csv")
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
# hello.csv, gdrive-- folder-hello.csv,read from pandas
# any csv file and create connecton with the sql + python and read krega each record ko and insert into sql .two file insert.py or fetch.py insert.py-- code of insert 
# pd.read_sql function

# %% [markdown]
# <h4> create a app that decide/ suggest which crop is suitable according to the farmer;s data</h4>
# <h4> use unsupervised algorithms - do grouping/clustring base on the similarity . use unlabeled data (only x varaible exist)</h4>

# %%
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# chickpea       100
# kidneybeans    100
# pigeonpeas     100
# mothbeans      100
# mungbean       100
# blackgram      100
# lentil         100
# pomegranate    100
# banana         100
# mango          100
# grapes         100
# watermelon     100
# muskmelon      100
# apple          100
# orange         100
# papaya         100
# coconut        100
# cotton         100
# jute           100
# coffee         100
# Name: count, dtype: int64

# %%
df['label'].nunique()
# Out:
# 22

# %%
rice=df[df['label']=="rice"]
rice
# Out:
#      N   P   K  temperature   humidity        ph    rainfall label
# 0   90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1   85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2   60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3   74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4   78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# ..  ..  ..  ..          ...        ...       ...         ...   ...
# 95  88  46  42    22.683191  83.463583  6.604993  194.265172  rice
# 96  93  47  37    21.533463  82.140041  6.500343  295.924880  rice
# 97  60  55  45    21.408658  83.329319  5.935745  287.576694  rice
# 98  78  35  44    26.543481  84.673536  7.072656  183.622266  rice
# 99  65  37  40    23.359054  83.595123  5.333323  188.413665  rice
#
# [100 rows x 8 columns]

# %%
coconut=df[df['label']=="coconut"]
coconut.head()
# Out:
#        N   P   K  temperature   humidity        ph    rainfall    label
# 1800  18  30  29    26.762749  92.860569  6.420019  224.590366  coconut
# 1801  37  23  28    25.612944  94.313884  5.740055  224.320676  coconut
# 1802  13  28  33    28.130115  95.648076  5.686973  151.076190  coconut
# 1803   2  21  35    25.028872  91.537209  6.293662  179.824894  coconut
# 1804  10  18  35    27.797977  99.645730  6.381975  181.694228  coconut

# %%
# rice['N'].mean()    # average nitrogen of rice
rice['temperature'].mean()
# Out:
# np.float64(23.6893322105)

# %%
# coconut['N'].mean()
coconut['temperature'].mean()
# Out:
# np.float64(27.409892172299998)

# %%
grouped=df.groupby('label')

# %%
grouped[['temperature']].mean()  # mean temp for all crops according to the temp
# Out:
#              temperature
# label
# apple          22.630942
# banana         27.376798
# blackgram      29.973340
# chickpea       18.872847
# coconut        27.409892
# coffee         25.540477
# cotton         23.988958
# grapes         23.849575
# jute           24.958376
# kidneybeans    20.115085
# lentil         24.509052
# maize          22.389204
# mango          31.208770
# mothbeans      28.194920
# mungbean       28.525775
# muskmelon      28.663066
# orange         22.765725
# papaya         33.723859
# pigeonpeas     27.741762
# pomegranate    21.837842
# rice           23.689332
# watermelon     25.591767

# %%
grouped[['N']].mean()
# Out:
#                   N
# label
# apple         20.80
# banana       100.23
# blackgram     40.02
# chickpea      40.09
# coconut       21.98
# coffee       101.20
# cotton       117.77
# grapes        23.18
# jute          78.40
# kidneybeans   20.75
# lentil        18.77
# maize         77.76
# mango         20.07
# mothbeans     21.44
# mungbean      20.99
# muskmelon    100.32
# orange        19.58
# papaya        49.88
# pigeonpeas    20.73
# pomegranate   18.87
# rice          79.89
# watermelon    99.42

# %%
df['temperature'].min()
# Out:
# np.float64(8.825674745)

# %%
df['temperature'].max()
# Out:
# np.float64(43.67549305)

# %%
df['temperature'].min()
# Out:
# np.float64(8.825674745)

# %%
df['temperature'].mean()
# Out:
# np.float64(25.616243851779544)

# %%
grouped['temperature'].agg(['min', 'max', 'mean'])
# Out:
#                    min        max       mean
# label
# apple        21.036527  23.996862  22.630942
# banana       25.010185  29.908885  27.376798
# blackgram    25.097374  34.946616  29.973340
# chickpea     17.024985  20.995022  18.872847
# coconut      25.008724  29.869083  27.409892
# coffee       23.059519  27.923744  25.540477
# cotton       22.000851  25.992374  23.988958
# grapes        8.825675  41.948657  23.849575
# jute         23.094338  26.985822  24.958376
# kidneybeans  15.330426  24.923601  20.115085
# lentil       18.064861  29.944139  24.509052
# maize        18.041855  26.549864  22.389204
# mango        27.003155  35.990097  31.208770
# mothbeans    24.018254  31.999286  28.194920
# mungbean     27.014704  29.914544  28.525775
# muskmelon    27.024151  29.943492  28.663066
# orange       10.010813  34.906653  22.765725
# papaya       23.012402  43.675493  33.723859
# pigeonpeas   18.319104  36.977944  27.741762
# pomegranate  18.071330  24.962732  21.837842
# ...

# %%
plt.bar('label','min')
# Out:
# <BarContainer object of 1 artists>
